# %%
import numpy as np
import pandas as pd
import yfinance as yf
import os

from market_ml.data_loader import DataLoader

# %%
DL = DataLoader()

DL.download_data()
# Out:
# ...
# Downloaded data for SPY
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00   83.862019   84.623245   83.220198   84.578468
# 2010-01-05 00:00:00-05:00   84.526240   84.839686   84.220253   84.802368
# 2010-01-06 00:00:00-05:00   84.720284   85.071047   84.653120   84.862083
# 2010-01-07 00:00:00-05:00   84.705394   85.324827   84.466577   85.220345
# 2010-01-08 00:00:00-05:00   84.996420   85.541224   84.824774   85.503906
# ...                               ...         ...         ...         ...
# 2026-07-07 00:00:00-04:00  750.219971  750.960022  745.210022  747.710022
# 2026-07-08 00:00:00-04:00  743.159973  746.150024  739.510010  745.400024
# 2026-07-09 00:00:00-04:00  747.349976  751.969971  745.590027  751.710022
# 2026-07-10 00:00:00-04:00  752.049988  755.419983  748.099976  754.950012
# 2026-07-13 00:00:00-04:00  752.469971  753.910522  750.315002  751.565002
#
# ...

# %%
dl = DataLoader()

dl.load_data()

dl.save_data()

dl.load_data()
