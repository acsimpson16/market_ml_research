# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from market_ml.data_loader import DataLoader

# %% [markdown]
# Downloading the SPY Data

# %%
tickers = ["SPY"]
start_date = "2010-01-01"

# %%
DL = DataLoader(ticker=tickers[0])
DL.download_data()
DL.save_data()
spy_data = DL.load_data()
DL.check_data()
# Out:
# Downloaded data for SPY
# Data saved for SPY
# Data loaded for SPY
# {'Number of NaNs': np.int64(0),
#  'Number of Rows': 19,
#  'Number of Columns': 8,
#  'Start': Timestamp('2026-06-15 00:00:00-0400', tz='UTC-04:00'),
#  'End': Timestamp('2026-07-13 00:00:00-0400', tz='UTC-04:00')}
