# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from market_ml.data_loader import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# Downloading the SPY Data

# %%
tickers = ["SPY"]
start_date = "2010-01-01"

# %%
DL = DataLoader(ticker=tickers[0], period='10y', interval='1d')
DL.download_data()
DL.save_data()
spy_data = DL.load_data()
DL.check_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Downloaded data for SPY
# Data saved for SPY
# Data loaded for SPY
# {'Missing Values': np.int64(0),
#  'Number of Rows': 2512,
#  'Number of Columns': 5,
#  'Start': Close    1970-01-01 00:00:00.000000178
#  High     1970-01-01 00:00:00.000000179
#  Low      1970-01-01 00:00:00.000000177
#  Open     1970-01-01 00:00:00.000000178
#  Volume   1970-01-01 00:00:00.020270000
#  dtype: datetime64[ns],
#  'End': Timestamp('2026-09-23 00:00:00'),
#  'Duplicate Dates': np.int64(0)}

# %%
spy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 spy
#
# NameError: name 'spy' is not defined
